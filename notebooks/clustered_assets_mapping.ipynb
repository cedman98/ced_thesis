# %%
# %cd ../
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/ced/bachelor/final

# %% [markdown]
# # Clustered Renewable Energy Asset Centroids in Brandenburg
#
# This notebook visualizes the capacity-weighted centroids of wind and solar installations across Brandenburg. These centroids optimize Numerical Weather Prediction (NWP) API query locations while maintaining meteorological representation.
#
# * **Wind Fleet**: Clustered via Haversine DBSCAN ($3.0 \text{ km}$ radius).
# * **Utility Solar**: Clustered via Haversine DBSCAN ($2.0 \text{ km}$ radius).
# * **Distributed Solar**: Grouped via a static geographic grid ($0.1^\circ$ resolution).

# %%
import pandas as pd
import folium
import geopandas as gpd
import numpy as np

# Load datasets
wind_df = pd.read_csv('./data/processed/wind_clusters.csv')
solar_df = pd.read_csv('./data/processed/solar_clusters.csv')
boundary_path = './data/external/brandenburg_boundary.geojson'

# Brandenburg Centroid
map_center = [52.35, 13.0]

# %% [markdown]
# ## 1. Wind Fleet Clusters Map
#
# Teal circles represent wind clusters. The radius of each circle corresponds to the square root of the cluster's capacity (MW) for visibility. Hover or click on a cluster to see detailed stats.

# %%
# Create the Wind map
m_wind = folium.Map(location=map_center, zoom_start=8, tiles='cartodbpositron')

# Add Brandenburg boundary outline
try:
    boundary = gpd.read_file(boundary_path)
    folium.GeoJson(
        boundary, 
        style_function=lambda x: {'fillColor': '#ffffff', 'color': '#333333', 'weight': 1.5, 'fillOpacity': 0.1}
    ).add_to(m_wind)
except Exception as e:
    print(f"Could not load boundary: {e}")

# Add wind clusters
for _, row in wind_df.iterrows():
    # Scale radius based on capacity
    radius = np.sqrt(row['total_capacity_mw']) * 1.5 + 2.0
    
    popup_text = f"""
    <b>Cluster ID:</b> {row['cluster_id']}<br>
    <b>Centroid:</b> ({row['centroid_lat']:.4f}, {row['centroid_lon']:.4f})<br>
    <b>Capacity:</b> {row['total_capacity_mw']:.2f} MW<br>
    <b>Asset Count:</b> {int(row['asset_count'])}
    """
    
    folium.CircleMarker(
        location=[row['centroid_lat'], row['centroid_lon']],
        radius=radius,
        color='#008080',
        fill=True,
        fill_color='#00cbcb',
        fill_opacity=0.7,
        popup=folium.Popup(popup_text, max_width=250),
        tooltip=f"{row['cluster_id']}: {row['total_capacity_mw']:.1f} MW"
    ).add_to(m_wind)

m_wind
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cc0b561d1d31eac3b4672500a33afaf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cc0b561d1d31eac3b4672500a33afaf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cc0b561d1d31eac3b4672500a33afaf = L.map(
#                 &quot;map_4cc0b561d1d31eac3b4672500a33afaf&quot;,
#                 {
#                     center: [52.35, 13.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9bf48b7f1d00eec4543e79136556f8e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9bf48b7f1d00eec4543e79136556f8e.addTo(map_4cc0b561d1d31eac3b4672500a33afaf);
#
#
#         function geo_json_fc5d47f713522b34e35e4b823c4acffa_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#ffffff&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_fc5d47f713522b34e35e4b823c4acffa_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json
# %% [markdown]
# ## 2. Utility-Scale Solar Clusters Map
#
# Orange circles represent large ground-mounted solar installations grouped with a strict $2.0 \text{ km}$ DBSCAN radius.

# %%
# Create the Utility Solar map
m_solar_utility = folium.Map(location=map_center, zoom_start=8, tiles='cartodbpositron')

# Add boundary
try:
    folium.GeoJson(
        boundary, 
        style_function=lambda x: {'fillColor': '#ffffff', 'color': '#333333', 'weight': 1.5, 'fillOpacity': 0.1}
    ).add_to(m_solar_utility)
except Exception as e:
    pass

# Filter for utility-scale solar
utility_df = solar_df[solar_df['track_type'] == 'utility']

# Add utility solar clusters
for _, row in utility_df.iterrows():
    radius = np.sqrt(row['total_capacity_mw']) * 1.2 + 2.0
    
    popup_text = f"""
    <b>Cluster ID:</b> {row['cluster_id']}<br>
    <b>Centroid:</b> ({row['centroid_lat']:.4f}, {row['centroid_lon']:.4f})<br>
    <b>Capacity:</b> {row['total_capacity_mw']:.2f} MW<br>
    <b>Asset Count:</b> {int(row['asset_count'])}
    """
    
    folium.CircleMarker(
        location=[row['centroid_lat'], row['centroid_lon']],
        radius=radius,
        color='#ff5722',
        fill=True,
        fill_color='#ff8a50',
        fill_opacity=0.7,
        popup=folium.Popup(popup_text, max_width=250),
        tooltip=f"{row['cluster_id']}: {row['total_capacity_mw']:.1f} MW"
    ).add_to(m_solar_utility)

m_solar_utility
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3dfec845c54d6f3b4170536c7f51c32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3dfec845c54d6f3b4170536c7f51c32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3dfec845c54d6f3b4170536c7f51c32 = L.map(
#                 &quot;map_a3dfec845c54d6f3b4170536c7f51c32&quot;,
#                 {
#                     center: [52.35, 13.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4ff3b24df80cc27bedc56759fb4a034 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4ff3b24df80cc27bedc56759fb4a034.addTo(map_a3dfec845c54d6f3b4170536c7f51c32);
#
#
#         function geo_json_2d5a11b08921d731d7bef186efa9dc2f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#ffffff&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_2d5a11b08921d731d7bef186efa9dc2f_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2d5a11b08921d731d7bef186efa9dc2f = L.geoJson(null, {
#                 onEachFeature: geo_json_2d5a11b08921d731d7bef186efa9dc2f_onEachFeature,
#
#                 style: geo_json_2d5a11b08921d731d7bef186efa9dc2f_styler,
#             ...{
# }
#         });
#
#         function geo_json_2d5a11b08921d731d7bef186efa9dc2f_add (data) {
#             geo_json_2d5a11b08921d731d7bef186efa9dc2f
#                 .addData(data);
#         }
#             geo_json_2d5a11b08921d731d7bef186efa9dc2f_add({&quot;bbox&quot;: [11.2657725, 51.359064, 14.7658159, 53.5590617], &quot;features&quot;: [{&quot;bbox&quot;: [11.2657725, 51.359064, 14.7658159, 53.5590617], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[
    folium.GeoJson(
        boundary, 
        style_function=lambda x: {'fillColor': '#ffffff', 'color': '#333333', 'weight': 1.5, 'fillOpacity': 0.1}
    ).add_to(m_solar_dist)
except Exception as e:
    pass

# Filter for distributed solar
dist_df = solar_df[solar_df['track_type'] == 'distributed']

# Add distributed solar cells
for _, row in dist_df.iterrows():
    radius = np.sqrt(row['total_capacity_mw']) * 0.8 + 2.0
    
    popup_text = f"""
    <b>Grid Cell Centroid:</b> ({row['centroid_lat']:.2f}, {row['centroid_lon']:.2f})<br>
    <b>Total Capacity:</b> {row['total_capacity_mw']:.2f} MW<br>
    <b>Asset Count:</b> {int(row['asset_count'])}
    """
    
    folium.CircleMarker(
        location=[row['centroid_lat'], row['centroid_lon']],
        radius=radius,
        color='#7b1fa2',
        fill=True,
        fill_color='#ba68c8',
        fill_opacity=0.6,
        popup=folium.Popup(popup_text, max_width=250),
        tooltip=f"Grid Cell: {row['total_capacity_mw']:.1f} MW"
    ).add_to(m_solar_dist)

m_solar_dist
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7bb30c34bc99b013dbbbc7469ae917e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7bb30c34bc99b013dbbbc7469ae917e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7bb30c34bc99b013dbbbc7469ae917e6 = L.map(
#                 &quot;map_7bb30c34bc99b013dbbbc7469ae917e6&quot;,
#                 {
#                     center: [52.35, 13.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b97e24870828c7bc670674491139be0e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b97e24870828c7bc670674491139be0e.addTo(map_7bb30c34bc99b013dbbbc7469ae917e6);
#
#
#         function geo_json_4567bfe31525a5efa7c3d88af0934639_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#333333&quot;, &quot;fillColor&quot;: &quot;#ffffff&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_4567bfe31525a5efa7c3d88af0934639_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_4567bfe31525a5efa7c3d88af0934639 = L.geoJson(null, {
#                 onEachFeature: geo_json_4567bfe31525a5efa7c3d88af0934639_onEachFeature,
#
#                 style: geo_json_4567bfe31525a5efa7c3d88af0934639_styler,
#             ...{
# }
#         });
#
#         function geo_json_4567bfe31525a5efa7c3d88af0934639_add (data) {
#             geo_json_4567bfe31525a5efa7c3d88af0934639
#                 .addData(data);
#         }
#             geo_json_4567bfe31525a5efa7c3d88af0934639_add({&quot;bbox&quot;: [11.2657725, 51.359064, 14.7658159, 53.5590617], &quot;features&quot;: [{&quot;bbox&quot;: [11.2657725, 51.359064, 14.7658159, 53.5590617], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[11.2695303, 53.1217698], [11.2710563, 53.1218343], [11.2740812, 53.121183], [11.2741216, 53.1212173], [11.2746343, 53.1210693], [11.2749902, 53.1210121], [11.2753064, 53.1209905], [11.2755325, 53.1210097], [11.2760489, 53.121068], [11.2761396, 53.1209885], [11.2785105, 53.1213986], [11.2786969, 53.1212918], [11.2793525, 53.1213572], [11.2800325, 53.1213758], [11.281838, 53.1213442], [11.283229, 53.1214596], [11.2834748, 53.1203542], [11.2836352, 53.120098], [11.2838212, 53.1199157], [11.2840677, 53.1198809], [11.2856672, 53.1200579], [11.2856174, 53.1197037], [11.2879421, 53.1193535], [11.2879936, 53.1187603], [11.2897778, 53.1188975], [11.2899482, 53.1186988], [11.2900603, 53.1179394], [11.2900695, 53.1174361], [11.2904008, 53.1169125], [11.2923675, 53.1169763], [11.2930551, 53.1169733], [11.2940899, 53.1167389], [11.2949793, 53.116682], [11.298674, 53.1168812], [11.298688, 53.1168491], [11.2987398, 53.1167756], [11.2988463, 53.1166528], [11.298956, 53.1165692], [11.2990396, 53.1165167], [11.2992338, 53.1164405], [11.2995093, 53.1163846], [11.3000497, 53.1163534], [11.3001064, 53.116354], [11.3003101, 53.1163792], [11.3003756, 53.1163833], [11.3010626, 53.1164793], [11.3016122, 53.1166107], [11.3020377, 53.1167477], [11.3027481, 53.1169094], [11.3028726, 53.1169244], [11.3031703, 53.1169427], [11.3032328, 53.1169431], [11.3036266, 53.1169289], [11.3037246, 53.1169], [11.3041403, 53.1167383], [11.3042764, 53.1166467], [11.3044343, 53.1165912], [11.3044957, 53.1165483], [11.3045552, 53.1164015], [11.304712, 53.1162952], [11.3049957, 53.1161582], [11.3050447, 53.1161494], [11.3052608, 53.1161275], [11.3054571, 53.1161491], [11.3057241, 53.1162048], [11.3058725, 53.1162557], [11.3061434, 53.1163891], [11.3065666, 53.1165273], [11.3067786, 53.1165587], [11.3070907, 53.1165958], [11.3074346, 53.1165681], [11.3076334, 53.1165382], [11.3082385, 53.1163851], [11.308726, 53.1162198], [11.3090951, 53.1160388], [11.3091895, 53.1160124], [11.3094216, 53.1158879], [11.3098973, 53.1158834], [11.3103112, 53.1159947], [11.3104232, 53.1160568], [11.310479, 53.1161364], [11.3109256, 53.116461], [11.3109712, 53.1165301], [11.31104, 53.1165565], [11.3110789, 53.1165943], [11.3110648, 53.1166144], [11.3111828, 53.1167456], [11.3112962, 53.1168566], [11.3115329, 53.1170636], [11.3121506, 53.1175344], [11.312414, 53.1176769], [11.3126658, 53.1177876], [11.3135383, 53.1180551], [11.3141185, 53.1182425], [11.3142101, 53.1183512], [11.3149274, 53.1183842], [11.3152032, 53.1184015], [11.3156075, 53.1184042], [11.3157273, 53.1184142], [11.3162574, 53.1185458], [11.316406

# %% [markdown]
# ## 4. Open-Meteo Query Coordinates Summary
#
# The following summary displays the exact number of coordinate centroids at which Numerical Weather Prediction (NWP) data will need to be downloaded from the Open-Meteo API.

# %%
# Print the exact coordinate counts for API querying
num_wind_pts = len(wind_df)
num_solar_utility_pts = len(solar_df[solar_df['track_type'] == 'utility'])
num_solar_dist_pts = len(solar_df[solar_df['track_type'] == 'distributed'])
total_api_points = num_wind_pts + num_solar_utility_pts + num_solar_dist_pts

print("Open-Meteo Query Points Summary:")
print(f"  - Wind Centroids: {num_wind_pts} coordinates")
print(f"  - Utility-scale Solar Centroids: {num_solar_utility_pts} coordinates")
print(f"  - Distributed Solar Grid Centroids: {num_solar_dist_pts} coordinates")
print(f"  - Total unique weather query locations: {total_api_points} points")
# Out:
# Open-Meteo Query Points Summary:
#   - Wind Centroids: 211 coordinates
#   - Utility-scale Solar Centroids: 455 coordinates
#   - Distributed Solar Grid Centroids: 427 coordinates
#   - Total unique weather query locations: 1093 points
